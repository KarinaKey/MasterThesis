# %%
import pandas as pd
import cv2
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# %%
df = pd.read_csv('marking.csv')

# %%
df.head()
# Out:
#     sample_id               text  \
# 0     aa1.png            Молдова
# 1  aa1007.png  продолжила борьбу
# 2   aa101.png      разработанные
# 3  aa1012.png              Плачи
# 4  aa1013.png        Гимны богам
#
#                                                 path  stage
# 0     D:/MMF/THESIS/CyrilHandWr_StackMix/img/aa1.png  valid
# 1  D:/MMF/THESIS/CyrilHandWr_StackMix/img/aa1007.png  train
# 2   D:/MMF/THESIS/CyrilHandWr_StackMix/img/aa101.png  train
# 3  D:/MMF/THESIS/CyrilHandWr_StackMix/img/aa1012.png  train
# 4  D:/MMF/THESIS/CyrilHandWr_StackMix/img/aa1013.png  train

# %%
idx = 0
sample = df.iloc[idx]
image_id = sample.name
print(sample.path)
image = cv2.imread(f'{sample.path}')
text = sample['text']

print('stage:', sample['stage'])
print('text:', text)
print('image_shape:', image.shape)

plt.figure(num=None, figsize=(12, 3), dpi=120, facecolor='w', edgecolor='k')
plt.imshow(image);
# Out:
# D:/MMF/THESIS/CyrilHandWr_StackMix/img/aa1.png
# stage: valid
# text: Молдова
# image_shape: (40, 238, 3)

# %%
from skimage import io

# %% [markdown]
# # Median filter.

# %%
def median_subtract(noisy_img, mask_size):
    background=cv2.medianBlur(noisy_img, mask_size)
    result=cv2.subtract(background, noisy_img)
    result=cv2.bitwise_not(result)
    return (result, background)

# %%
sample['path']
# Out:
# 'D:/MMF/THESIS/CyrilHandWr_StackMix/img/aa1.png'

# %%
dirty_img = io.imread(sample['path'])

# %%
dirty_img;

# %%
result, background=median_subtract(dirty_img, 19)
fig, axarr= plt.subplots(1,3, figsize=(15,15))
axarr[0].imshow(dirty_img, cmap='gray')
axarr[1].imshow(background, cmap='gray')
axarr[2].imshow(result, cmap='gray')

# %%
result, background=median_subtract(dirty_img, 11)
fig, axarr= plt.subplots(1,3, figsize=(15,15))
axarr[0].imshow(dirty_img, cmap='gray')
axarr[1].imshow(background, cmap='gray')
axarr[2].imshow(result, cmap='gray')

# %%
idx = 1
sample = df.iloc[idx]
image_id = sample.name
print(sample.path)
image = cv2.imread(f'{sample.path}')
text = sample['text']

print('stage:', sample['stage'])
print('text:', text)
print('image_shape:', image.shape)

plt.figure(num=None, figsize=(12, 3), dpi=120, facecolor='w', edgecolor='k')
plt.imshow(image);
# Out:
# D:/MMF/THESIS/CyrilHandWr_StackMix/img/aa1007.png
# stage: train
# text: продолжила борьбу
# image_shape: (36, 256, 3)

# %%
dirty_img = io.imread(sample['path'])

# %%
result, background=median_subtract(dirty_img, 33)
fig, axarr= plt.subplots(1,3, figsize=(15,15))
axarr[0].imshow(dirty_img, cmap='gray')
axarr[1].imshow(background, cmap='gray')
axarr[2].imshow(result, cmap='gray')

# %%
idx = 3
sample = df.iloc[idx]
image_id = sample.name
print(sample.path)
image = cv2.imread(f'{sample.path}')
text = sample['text']

print('stage:', sample['stage'])
print('text:', text)
print('image_shape:', image.shape)

plt.figure(num=None, figsize=(12, 3), dpi=120, facecolor='w', edgecolor='k')
plt.imshow(image);
# Out:
# D:/MMF/THESIS/CyrilHandWr_StackMix/img/aa1012.png
# stage: train
# text: Плачи
# image_shape: (48, 126, 3)

# %%
dirty_img = io.imread(sample['path'])

# %%
result, background=median_subtract(dirty_img, 33)
fig, axarr= plt.subplots(1,3, figsize=(15,15))
axarr[0].imshow(dirty_img, cmap='gray')
axarr[1].imshow(background, cmap='gray')
axarr[2].imshow(result, cmap='gray')

# %%
df[df['text'].str.contains('краина')]
# Out:
#         sample_id     text                                               path  \
# 2578      aa3.png  Украина     D:/MMF/THESIS/CyrilHandWr_StackMix/img/aa3.png
# 19377   aw814.png  Украина   D:/MMF/THESIS/CyrilHandWr_StackMix/img/aw814.png
# 19378   aw815.png  Украина   D:/MMF/THESIS/CyrilHandWr_StackMix/img/aw815.png
# 19386   aw831.png  Украина   D:/MMF/THESIS/CyrilHandWr_StackMix/img/aw831.png
# 19387   aw832.png  Украина   D:/MMF/THESIS/CyrilHandWr_StackMix/img/aw832.png
# 19393   aw842.png  Украина   D:/MMF/THESIS/CyrilHandWr_StackMix/img/aw842.png
# 19394   aw844.png  Украина   D:/MMF/THESIS/CyrilHandWr_StackMix/img/aw844.png
# 19409  aw8812.png  Украина  D:/MMF/THESIS/CyrilHandWr_StackMix/img/aw8812.png
# 19411  aw8825.png  Украина  D:/MMF/THESIS/CyrilHandWr_StackMix/img/aw8825.png
# 19415  aw8833.png  Украина  D:/MMF/THESIS/CyrilHandWr_StackMix/img/aw8833.png
# 19416  aw8837.png  Украина  D:/MMF/THESIS/CyrilHandWr_StackMix/img/aw8837.png
# ...

# %%
idx = 2045
sample = df.iloc[idx]
image_id = sample.name
print(sample.path)
image = cv2.imread(f'{sample.path}')
text = sample['text']

print('stage:', sample['stage'])
print('text:', text)
print('image_shape:', image.shape)

plt.figure(num=None, figsize=(12, 3), dpi=120, facecolor='w', edgecolor='k')
plt.imshow(image);
# Out:
# D:/MMF/THESIS/CyrilHandWr_StackMix/img/aa2.png
# stage: train
# text: ГУ МВД
# image_shape: (55, 173, 3)

# %%
dirty_img = io.imread(sample['path'])

# %%
result, background=median_subtract(dirty_img, 33)
fig, axarr= plt.subplots(1,3, figsize=(15,15))
axarr[0].imshow(dirty_img, cmap='gray')
axarr[1].imshow(background, cmap='gray')
axarr[2].imshow(result, cmap='gray')

# %%
df
# Out:
#           sample_id                   text  \
# 0           aa1.png                Молдова
# 1        aa1007.png      продолжила борьбу
# 2         aa101.png          разработанные
# 3        aa1012.png                  Плачи
# 4        aa1013.png            Гимны богам
# ...             ...                    ...
# 73809  yob20539.png  Ответственность в/сл-
# 73810  yob20543.png             независимо
# 73811  yob20544.png    от воинского звания
# 73812  yob20545.png               воинской
# 73813  yob20546.png         должности рав-
#
#                                                     path  stage
# 0         D:/MMF/THESIS/CyrilHandWr_StackMix/img/aa1.png  valid
# 1      D:/MMF/THESIS/CyrilHandWr_StackMix/img/aa1007.png  train
# 2       D:/MMF/THESIS/CyrilHandWr_StackMix/img/aa101.png  train
# 3      D:/MMF/THESIS/CyrilHandWr_StackMix/img/aa1012.png  train
# 4      D:/MMF/THESIS/CyrilHandWr_StackMix/img/aa1013.png  train
# ...

# %%
from time import sleep
from progress.bar import Bar

# %%
from tqdm import tqdm
from time import sleep

# %%
len(df)
# Out:
# 73814

# %%
for i, row in tqdm(df.iterrows(), total=len(df)):
    image = cv2.imread(f'{row.path}')
    result, background=median_subtract(image, 33)
    img = Image.fromarray(result)
    img.save(f"D:/MMF/THESIS/NoNoise_noChoice/medfilter/{row['sample_id']}")
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 73814/73814 [3:45:29<00:00,  5.46it/s]

# %%
idx = 2578
sample = df.iloc[idx]
image_id = sample.name
print(sample.path)
image = cv2.imread(f'{sample.path}')
text = sample['text']

print('stage:', sample['stage'])
print('text:', text)
print('image_shape:', image.shape)

plt.figure(num=None, figsize=(12, 3), dpi=120, facecolor='w', edgecolor='k')
plt.imshow(image);
# Out:
# D:/MMF/THESIS/CyrilHandWr_StackMix/img/aa3.png
# stage: train
# text: Украина
# image_shape: (64, 248, 3)

# %%
dirty_img = io.imread(sample['path'])

# %%
result, background=median_subtract(dirty_img, 33)
fig, axarr= plt.subplots(1,3, figsize=(15,15))
axarr[0].imshow(dirty_img, cmap='gray')
axarr[1].imshow(background, cmap='gray')
axarr[2].imshow(result, cmap='gray')

# %%
df[df['text'].str.contains('инши')]
# Out:
# Empty DataFrame
# Columns: [sample_id, text, path, stage]
# Index: []

# %% [markdown]
# # Edge Detection, Dilation & Erosion (EDE Method)

# %%
def edge_detection_dilation_erosion(noisy_img, t):
    edges=cv2.Canny(noisy_img, t, t)
    edges=cv2.bitwise_not(edges)
    kernel = np.ones((3,3),np.uint8)
    dilation = cv2.dilate(cv2.bitwise_not(edges),kernel,iterations = 1)
    dilation=cv2.bitwise_not(dilation)
    kernel1 = np.ones((5,5),np.uint8)
    erosion=cv2.erode(cv2.bitwise_not(dilation), kernel1,iterations=1)
    erosion=cv2.bitwise_not(erosion)
    return (edges, dilation, erosion)

# %%
idx = 0
sample = df.iloc[idx]
image_id = sample.name
print(sample.path)
image = cv2.imread(f'{sample.path}')
text = sample['text']

print('stage:', sample['stage'])
print('text:', text)
print('image_shape:', image.shape)

plt.figure(num=None, figsize=(12, 3), dpi=120, facecolor='w', edgecolor='k')
plt.imshow(image);
# Out:
# D:/MMF/THESIS/CyrilHandWr_StackMix/img/aa1.png
# stage: valid
# text: Молдова
# image_shape: (40, 238, 3)

# %%
dirty_img = io.imread(sample['path'])

# %%
edges, dilation, erosion=edge_detection_dilation_erosion(dirty_img, 400)
fig, axarr= plt.subplots(2,2, figsize=(15,5))
axarr[0, 0].imshow(dirty_img, cmap='gray')
axarr[0, 1].imshow(edges, cmap='gray')
axarr[1, 0].imshow(dilation, cmap='gray')
axarr[1, 1].imshow(erosion, cmap='gray')

# %%
idx = 1
sample = df.iloc[idx]
image_id = sample.name
print(sample.path)
image = cv2.imread(f'{sample.path}')
text = sample['text']

print('stage:', sample['stage'])
print('text:', text)
print('image_shape:', image.shape)

plt.figure(num=None, figsize=(12, 3), dpi=120, facecolor='w', edgecolor='k')
plt.imshow(image);
# Out:
# D:/MMF/THESIS/CyrilHandWr_StackMix/img/aa1007.png
# stage: train
# text: продолжила борьбу
# image_shape: (36, 256, 3)

# %%
dirty_img = io.imread(sample['path'])

# %%
edges, dilation, erosion=edge_detection_dilation_erosion(dirty_img, 90)
fig, axarr= plt.subplots(2,2, figsize=(15,5))
axarr[0, 0].imshow(dirty_img, cmap='gray')
axarr[0, 1].imshow(edges, cmap='gray')
axarr[1, 0].imshow(dilation, cmap='gray')
axarr[1, 1].imshow(erosion, cmap='gray')

# %% [markdown]
# # Adaptive thresholding

# %%
def adaptive_thresholding(noisy_img, blockSize, C):
    adaptive_th=cv2.adaptiveThreshold(noisy_img, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, blockSize, C)
    return adaptive_th

# %%
idx = 0
sample = df.iloc[idx]
image_id = sample.name
print(sample.path)
image = cv2.imread(f'{sample.path}')
text = sample['text']

print('stage:', sample['stage'])
print('text:', text)
print('image_shape:', image.shape)

plt.figure(num=None, figsize=(12, 3), dpi=120, facecolor='w', edgecolor='k')
plt.imshow(image);
# Out:
# D:/MMF/THESIS/CyrilHandWr_StackMix/img/aa1.png
# stage: valid
# text: Молдова
# image_shape: (40, 238, 3)

# %%
dirty_img = io.imread(sample['path'])
dirty_img = cv2.cvtColor(dirty_img, cv2.COLOR_BGR2GRAY)

# %%
adaptive_th=adaptive_thresholding(dirty_img, 15, 50)
fig, axarr= plt.subplots(1,2, figsize=(15,5))
axarr[0].imshow(dirty_img, cmap='gray')
axarr[1].imshow(adaptive_th, cmap='gray')

# %%
idx = 1
sample = df.iloc[idx]
image_id = sample.name
print(sample.path)
image = cv2.imread(f'{sample.path}')
text = sample['text']

print('stage:', sample['stage'])
print('text:', text)
print('image_shape:', image.shape)

plt.figure(num=None, figsize=(12, 3), dpi=120, facecolor='w', edgecolor='k')
plt.imshow(image);
# Out:
# D:/MMF/THESIS/CyrilHandWr_StackMix/img/aa1007.png
# stage: train
# text: продолжила борьбу
# image_shape: (36, 256, 3)

# %%
dirty_img = io.imread(sample['path'])
dirty_img = cv2.cvtColor(dirty_img, cv2.COLOR_BGR2GRAY)

# %%
adaptive_th=adaptive_thresholding(dirty_img, 21, 10)
fig, axarr= plt.subplots(1,2, figsize=(15,5))
axarr[0].imshow(dirty_img, cmap='gray')
axarr[1].imshow(adaptive_th, cmap='gray')

# %%
idx = 1
sample = df.iloc[idx]
image_id = sample.name
print(sample.path)
image = cv2.imread(f'{sample.path}')
text = sample['text']

print('stage:', sample['stage'])
print('text:', text)
print('image_shape:', image.shape)

plt.figure(num=None, figsize=(12, 3), dpi=120, facecolor='w', edgecolor='k')
plt.imshow(image);
# Out:
# D:/MMF/THESIS/CyrilHandWr_StackMix/img/aa1007.png
# stage: train
# text: продолжила борьбу
# image_shape: (36, 256, 3)

# %%
dirty_img = io.imread(sample['path'])
dirty_img = cv2.cvtColor(dirty_img, cv2.COLOR_BGR2GRAY)

# %%
adaptive_th=adaptive_thresholding(dirty_img, 15, 7)
fig, axarr= plt.subplots(1,2, figsize=(15,5))
axarr[0].imshow(dirty_img, cmap='gray')
axarr[1].imshow(adaptive_th, cmap='gray')

# %% [markdown]
# # Autoencoder

# %%
import os
from pathlib import Path
import glob

import numpy as np
import pandas as pd

from sklearn.metrics import mean_squared_error
from math import sqrt

from sewar.full_ref import uqi, psnr, rmse, ssim

import matplotlib.pyplot as plt
from skimage.io import imread, imshow, imsave
from keras.preprocessing.image import load_img, array_to_img, img_to_array
from keras.models import Sequential, Model
from keras.layers import Dense, Conv2D, MaxPooling2D, UpSampling2D, Flatten, Input
from keras.optimizers import SGD, Adam, Adadelta, Adagrad
from keras import backend as K
from sklearn.model_selection import train_test_split
np.random.seed(111)

# %%
input_dir  = 'D:/MMF/THESIS/NoNoise_noChoice/dataset/'
train = f'{input_dir}/train'
train_cleaned = f'{input_dir}/train_cleaned'
test = f'{input_dir}/test'

# %%
train_images = os.listdir(train)
train_labels = os.listdir(train_cleaned)
test_images = os.listdir(test)

# %%
print("Total number of images in the training set: ", len(train_images))
print("Total number of cleaned images found: ", len(train_labels))
print("Total number of samples in the test set: ", len(test_images))
# Out:
# Total number of images in the training set:  144
# Total number of cleaned images found:  144
# Total number of samples in the test set:  72

# %%
samples = train_images[:3] + train_labels[:3]

f, ax = plt.subplots(2, 3, figsize=(20,10))
for i, img in enumerate(samples):
    if i//3 != 1:
        img = imread(f'{train}/{img}')
        ax[i//3, i%3].imshow(img, cmap='gray')
        ax[i//3, i%3].axis('off')
    else:
        img = imread(f'{train_cleaned}/{img}')
        ax[i//3, i%3].imshow(img, cmap='gray')
        ax[i//3, i%3].axis('off')
plt.show()

# %%
def build_autoencoder():
    input_img = Input(shape=(420,540,1), name='image_input')
    
    # Encoder 
    x = Conv2D(32, (3,3), activation='relu', padding='same', name='Conv1')(input_img)
    x = MaxPooling2D((2,2), padding='same', name='pool1')(x)
    x = Conv2D(64, (3,3), activation='relu', padding='same', name='Conv2')(x)
    x = MaxPooling2D((2,2), padding='same', name='pool2')(x)
    
    # Decoder
    x = Conv2D(64, (3,3), activation='relu', padding='same', name='Conv3')(x)
    x = UpSampling2D((2,2), name='upsample1')(x)
    x = Conv2D(32, (3,3), activation='relu', padding='same', name='Conv4')(x)
    x = UpSampling2D((2,2), name='upsample2')(x)
    x = Conv2D(1, (3,3), activation='sigmoid', padding='same', name='Conv5')(x)
    
    # Model
    autoencoder = Model(inputs=input_img, outputs=x)
    autoencoder.compile(optimizer='adam', loss='binary_crossentropy')
    
    return autoencoder

# %%
autoencoder = build_autoencoder()
autoencoder.summary()
# Out:
# Model: "model_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  image_input (InputLayer)    [(None, 420, 540, 1)]     0
#
#  Conv1 (Conv2D)              (None, 420, 540, 32)      320
#
#  pool1 (MaxPooling2D)        (None, 210, 270, 32)      0
#
#  Conv2 (Conv2D)              (None, 210, 270, 64)      18496
#
#  pool2 (MaxPooling2D)        (None, 105, 135, 64)      0
#
#  Conv3 (Conv2D)              (None, 105, 135, 64)      36928
#
#  upsample1 (UpSampling2D)    (None, 210, 270, 64)      0
#
#  Conv4 (Conv2D)              (None, 210, 270, 32)      18464
#
#  upsample2 (UpSampling2D)    (None, 420, 540, 32)      0
#
#  Conv5 (Conv2D)              (None, 420, 540, 1)       289
#
# ...
# Total params: 74497 (291.00 KB)
# Trainable params: 74497 (291.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
X = []
Y = []

for img in train_images:
    img = load_img(f'{train}/{img}', grayscale=True,target_size=(420,540))
    img = img_to_array(img).astype('float32')/255.
    X.append(img)

for img in train_labels:
    img = load_img(f'{train_cleaned}/{img}', grayscale=True,target_size=(420,540))
    img = img_to_array(img).astype('float32')/255.
    Y.append(img)


X = np.array(X)
Y = np.array(Y)

print("Size of X : ", X.shape)
print("Size of Y : ", Y.shape)
# Out:
# Size of X :  (144, 420, 540, 1)
# Size of Y :  (144, 420, 540, 1)

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X, Y, test_size=0.1, random_state=42)
print("Total number of training samples: ", X_train.shape)
print("Total number of validation samples: ", X_valid.shape)
# Out:
# Total number of training samples:  (129, 420, 540, 1)
# Total number of validation samples:  (15, 420, 540, 1)

# %%
autoencoder.fit(X_train, y_train, epochs=10, batch_size=8, validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/10
# 17/17 [==============================] - 48s 3s/step - loss: 0.4591 - val_loss: 0.3684
# Epoch 2/10
# 17/17 [==============================] - 44s 3s/step - loss: 0.3501 - val_loss: 0.3531
# Epoch 3/10
# 17/17 [==============================] - 41s 2s/step - loss: 0.3310 - val_loss: 0.3227
# Epoch 4/10
# 17/17 [==============================] - 41s 2s/step - loss: 0.2861 - val_loss: 0.2590
# Epoch 5/10
# 17/17 [==============================] - 40s 2s/step - loss: 0.2417 - val_loss: 0.2312
# Epoch 6/10
# 17/17 [==============================] - 42s 3s/step - loss: 0.2188 - val_loss: 0.2142
# Epoch 7/10
# 17/17 [==============================] - 41s 2s/step - loss: 0.2037 - val_loss: 0.2042
# Epoch 8/10
# 17/17 [==============================] - 42s 3s/step - loss: 0.1940 - val_loss: 0.1925
# Epoch 9/10
# 17/17 [==============================] - 41s 2s/step - loss: 0.1852 - val_loss: 0.1891
# Epoch 10/10
# ...

# %%
sample_test = load_img(f'{train}/{train_images[-1]}', grayscale=True, target_size=(420,540))
sample_test = img_to_array(sample_test)
sample_test_img = sample_test.astype('float32')/255.
sample_test_img = np.expand_dims(sample_test, axis=0)

# Get the predition
predicted_label = np.squeeze(autoencoder.predict(sample_test_img))

f, ax = plt.subplots(1,2, figsize=(10,8))
ax[0].imshow(np.squeeze(sample_test), cmap='gray')
ax[1].imshow(np.squeeze(predicted_label.astype('int8')), cmap='gray')

ax[0].set_title('Dirty image', color='#900c3f')
ax[1].set_title('Trained result', color='#900c3f')

plt.show()
# Out:
# 1/1 [==============================] - 0s 156ms/step

# %%
sample_test = load_img(f'D:/MMF/THESIS/Dataset_cleaned/train/aa30.png', grayscale=True, target_size=(420,540))
sample_test = img_to_array(sample_test)
sample_test_img = sample_test.astype('float32')/255.
sample_test_img = np.expand_dims(sample_test, axis=0)

# Get the predition
predicted_label = np.squeeze(autoencoder.predict(sample_test_img))

f, ax = plt.subplots(1,2, figsize=(10,8))
ax[0].imshow(np.squeeze(sample_test), cmap='gray')
ax[1].imshow(np.squeeze(predicted_label.astype('int8')), cmap='gray')

ax[0].set_title('Dirty image', color='#900c3f')
ax[1].set_title('Trained result', color='#900c3f')

plt.show()
# Out:
# 1/1 [==============================] - 0s 73ms/step

# %% [markdown]
# # My AutoEncoder

# %%
import os
from pathlib import Path
import glob

import numpy as np
import pandas as pd

from sklearn.metrics import mean_squared_error
from math import sqrt

from sewar.full_ref import uqi, psnr, rmse, ssim

import matplotlib.pyplot as plt
from skimage.io import imread, imshow, imsave
from keras.preprocessing.image import load_img, array_to_img, img_to_array
from keras.models import Sequential, Model
from keras.layers import Dense, Conv2D, MaxPooling2D, UpSampling2D, Flatten, Input
from keras.optimizers import SGD, Adam, Adadelta, Adagrad
from keras import backend as K
from sklearn.model_selection import train_test_split
np.random.seed(111)

# %%
input_dir  = 'D:/MMF/THESIS/Dataset_cleaned'
train = f'{input_dir}/train'
train_cleaned = f'{input_dir}/train_cleaned'
#test = f'{input_dir}/test'

# %%
train_images = os.listdir(train)
train_labels = os.listdir(train_cleaned)
#test_images = os.listdir(test)

# %%
print("Total number of images in the training set: ", len(train_images))
print("Total number of cleaned images found: ", len(train_labels))
#print("Total number of samples in the test set: ", len(test_images))
# Out:
# Total number of images in the training set:  64
# Total number of cleaned images found:  64

# %%
samples = train_images[:3] + train_labels[:3]

f, ax = plt.subplots(2, 3, figsize=(20,10))
for i, img in enumerate(samples):
    if i//3 != 1:
        img = imread(f'{train}/{img}')
        ax[i//3, i%3].imshow(img, cmap='gray')
        ax[i//3, i%3].axis('off')
    else:
        img = imread(f'{train_cleaned}/{img}')
        ax[i//3, i%3].imshow(img, cmap='gray')
        ax[i//3, i%3].axis('off')
plt.show()

# %%
arr1 = []
arr2 = []
for i in train_images:
    img = imread(f'{train}/{i}')
    a = img.shape
    arr1.append(a[0])
    arr2.append(a[1])

# %%
print(max(arr1), max(arr2))
# Out:
# 79 256

# %%
print(min(arr1), min(arr2))
# Out:
# 30 56

# %%
def build_autoencoder():
    input_img = Input(shape=(420, 540, 1), name='image_input')
    
    # Encoder 
    x = Conv2D(32, (3,3), activation='relu', padding='same', name='Conv1')(input_img)
    x = MaxPooling2D((2,2), padding='same', name='pool1')(x)
    x = Conv2D(64, (3,3), activation='relu', padding='same', name='Conv2')(x)
    x = MaxPooling2D((2,2), padding='same', name='pool2')(x)
    
    # Decoder
    x = Conv2D(64, (3,3), activation='relu', padding='same', name='Conv3')(x)
    x = UpSampling2D((2,2), name='upsample1')(x)
    x = Conv2D(32, (3,3), activation='relu', padding='same', name='Conv4')(x)
    x = UpSampling2D((2,2), name='upsample2')(x)
    x = Conv2D(1, (3,3), activation='sigmoid', padding='same', name='Conv5')(x)
    
    # Model
    autoencoder = Model(inputs=input_img, outputs=x)
    autoencoder.compile(optimizer='adam', loss='binary_crossentropy')
    
    return autoencoder

# %%
autoencoder = build_autoencoder()
autoencoder.summary()
# Out:
# Model: "model_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  image_input (InputLayer)    [(None, 420, 540, 1)]     0
#
#  Conv1 (Conv2D)              (None, 420, 540, 32)      320
#
#  pool1 (MaxPooling2D)        (None, 210, 270, 32)      0
#
#  Conv2 (Conv2D)              (None, 210, 270, 64)      18496
#
#  pool2 (MaxPooling2D)        (None, 105, 135, 64)      0
#
#  Conv3 (Conv2D)              (None, 105, 135, 64)      36928
#
#  upsample1 (UpSampling2D)    (None, 210, 270, 64)      0
#
#  Conv4 (Conv2D)              (None, 210, 270, 32)      18464
#
#  upsample2 (UpSampling2D)    (None, 420, 540, 32)      0
#
#  Conv5 (Conv2D)              (None, 420, 540, 1)       289
#
# ...
# Total params: 74497 (291.00 KB)
# Trainable params: 74497 (291.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
def img3D_create(a,M,N):
    p,q,r = a.shape
    out = np.zeros((M,N,r),dtype=a.dtype)
    out[:p,:q] = a
    return out

# %%
img = load_img(f'{train}/{train_images[0]}', grayscale=True)
img = img_to_array(img).astype('float32')/255.
img.shape
# Out:
# (40, 238, 1)

# %%
img3D_create(img, 80, 256).shape
# Out:
# (80, 256, 1)

# %%
img[:30, :56].shape
# Out:
# (30, 56, 1)

# %%
X = []
Y = []

for img in train_images:
    img = load_img(f'{train}/{img}', grayscale=True, target_size=(420, 540))
    img = img_to_array(img).astype('float32')/255.
    X.append(img)

for img in train_labels:
    img = load_img(f'{train_cleaned}/{img}', grayscale=True, target_size=(420, 540))
    img = img_to_array(img).astype('float32')/255.
    Y.append(img)


X = np.array(X)
Y = np.array(Y)

print("Size of X : ", X.shape)
print("Size of Y : ", Y.shape)
# Out:
# Size of X :  (64, 420, 540, 1)
# Size of Y :  (64, 420, 540, 1)

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X, Y, test_size=0.1, random_state=42)
print("Total number of training samples: ", X_train.shape)
print("Total number of validation samples: ", X_valid.shape)
# Out:
# Total number of training samples:  (57, 420, 540, 1)
# Total number of validation samples:  (7, 420, 540, 1)

# %%
autoencoder.fit(X_train, y_train, epochs=10, batch_size=8, validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/10
# 8/8 [==============================] - 17s 2s/step - loss: 0.2557 - val_loss: 0.2635
# Epoch 2/10
# 8/8 [==============================] - 16s 2s/step - loss: 0.2103 - val_loss: 0.2527
# Epoch 3/10
# 8/8 [==============================] - 17s 2s/step - loss: 0.2099 - val_loss: 0.2268
# Epoch 4/10
# 8/8 [==============================] - 17s 2s/step - loss: 0.1949 - val_loss: 0.2206
# Epoch 5/10
# 8/8 [==============================] - 17s 2s/step - loss: 0.1839 - val_loss: 0.2109
# Epoch 6/10
# 8/8 [==============================] - 17s 2s/step - loss: 0.1821 - val_loss: 0.1969
# Epoch 7/10
# 8/8 [==============================] - 17s 2s/step - loss: 0.1738 - val_loss: 0.1978
# Epoch 8/10
# 8/8 [==============================] - 17s 2s/step - loss: 0.1531 - val_loss: 0.1747
# Epoch 9/10
# 8/8 [==============================] - 16s 2s/step - loss: 0.1465 - val_loss: 0.1647
# Epoch 10/10
# ...

# %%
sample_test = load_img(f'{train}/{train_images[-1]}', grayscale=True)
sample_test = img_to_array(sample_test).astype('float32')/255.
sample_test = img3D_create(sample_test, 80, 256)

# %%
sample_test.shape
# Out:
# (80, 256, 1)

# %%
sample_test_img = np.expand_dims(sample_test, axis=0)
sample_test_img.shape
# Out:
# (1, 80, 256, 1)

# %%
sample_test = load_img(f'{train}/{train_images[1]}', grayscale=True, target_size=(420, 540))
sample_test = img_to_array(sample_test).astype('float32')/255.
sample_test_img = np.expand_dims(sample_test, axis=0)
test = load_img(f'{train_cleaned}/{train_images[1]}', grayscale=True, target_size=(420, 540))



# Get the predition
predicted_label = np.squeeze(autoencoder.predict(sample_test_img))

f, ax = plt.subplots(1,3, figsize=(10,8))
ax[0].imshow(np.squeeze(sample_test), cmap='gray')
ax[1].imshow(np.squeeze(predicted_label.astype('int8')), cmap='gray')
ax[2].imshow(np.squeeze(test), cmap='gray')


ax[0].set_title('Dirty image', color='#900c3f')
ax[1].set_title('Trained result', color='#900c3f')

plt.show()
# Out:
# 1/1 [==============================] - 0s 129ms/step

# %%
autoencoder.predict(sample_test_img)
# Out:
# 1/1 [==============================] - 0s 23ms/step
# array([[[[0.9831015 ],
#          [0.9932029 ],
#          [0.9944504 ],
#          [0.9955462 ],
#          [0.995997  ],
#          [0.9976047 ],
#          [0.9983672 ],
#          [0.9986785 ],
#          [0.99879616],
#          [0.99907124],
#          [0.9993466 ],
#          [0.99960595],
#          [0.9996925 ],
#          [0.9996795 ],
#          [0.9996123 ],
#          [0.99949694],
#          [0.9994095 ],
#          [0.9995031 ],
#          [0.9995782 ],
#          [0.9995948 ],
#          [0.9996029 ],
#          [0.99957854],
#          [0.99959075],
#          [0.9996727 ],
#          [0.99970895],
#          [0.9996919 ],
#          [0.99965936],
#          [0.999627  ],
#          [0.99960834],
#          [0.9996579 ],
#          [0.9996727 ],
#          [0.9995876 ],
#          [0.9995748 ],
#          [0.99960035],
#          [0.99967897],
#          [0.9998204 ],
#          [0.99986607],
# ...

# %%
sample_test
# Out:
# array([[[0.47843137],
#         [0.48235294],
#         [0.4862745 ],
#         ...,
#         [0.47843137],
#         [0.47843137],
#         [0.4745098 ]],
#
#        [[0.49019608],
#         [0.49019608],
#         [0.49019608],
#         ...,
#         [0.4862745 ],
#         [0.4862745 ],
#         [0.47843137]],
#
#        [[0.5019608 ],
#         [0.49411765],
#         [0.49803922],
#         ...,
#         [0.4862745 ],
#         [0.4862745 ],
#         [0.47843137]],
#
#        ...,
#
#        [[0.49411765],
#         [0.5137255 ],
#         [0.5176471 ],
#         ...,
#         [0.49019608],
#         [0.4862745 ],
#         [0.48235294]],
#
#        [[0.49411765],
#         [0.50980395],
#         [0.50980395],
#         ...,
#         [0.49019608],
#         [0.4862745 ],
#         [0.47843137]],
#
#        [[0.49803922],
#         [0.5058824 ],
#         [0.5058824 ],
#         ...,
#         [0.49019608],
#         [0.4862745 ],
# ...
